# %%
import pandas as pd

df = pd.read_csv('products.csv')
df
# Out:
#       key                                  name  \
# 0    0_bj                   Salted Caramel Core
# 1    1_bj                   Netflix & Chilll'd™
# 2    2_bj                          Chip Happens
# 3    3_bj                               Cannoli
# 4    4_bj                        Gimme S’more!™
# 5    5_bj             Peanut Butter Half Baked®
# 6    6_bj                Berry Sweet Mascarpone
# 7    7_bj         Chocolate Peanut Butter Split
# 8    8_bj                     Justice ReMix'd ™
# 9    9_bj                 Boots on the Moooo’n™
# 10  10_bj                      Americone Dream®
# 11  11_bj                     Bourbon Pecan Pie
# 12  12_bj                     Brewed to Matter™
# 13  13_bj          Caramel Chocolate Cheesecake
# 14  14_bj                        Cherry Garcia®
# 15  15_bj                   Chillin' the Roast™
# 16  16_bj           Chocolate Chip Cookie Dough
# 17  17_bj               Chocolate Fudge Brownie
# ...

# %%
df = df.astype({'rating': float, 'rating_count': int})
df
# Out:
#       key                                  name  \
# 0    0_bj                   Salted Caramel Core
# 1    1_bj                   Netflix & Chilll'd™
# 2    2_bj                          Chip Happens
# 3    3_bj                               Cannoli
# 4    4_bj                        Gimme S’more!™
# 5    5_bj             Peanut Butter Half Baked®
# 6    6_bj                Berry Sweet Mascarpone
# 7    7_bj         Chocolate Peanut Butter Split
# 8    8_bj                     Justice ReMix'd ™
# 9    9_bj                 Boots on the Moooo’n™
# 10  10_bj                      Americone Dream®
# 11  11_bj                     Bourbon Pecan Pie
# 12  12_bj                     Brewed to Matter™
# 13  13_bj          Caramel Chocolate Cheesecake
# 14  14_bj                        Cherry Garcia®
# 15  15_bj                   Chillin' the Roast™
# 16  16_bj           Chocolate Chip Cookie Dough
# 17  17_bj               Chocolate Fudge Brownie
# ...

# %%
df['name'] = df['name'].str.upper()
df['subhead'] = df['subhead'].str.upper()
df['description'] = df['description'].str.upper()
df
# Out:
#       key                                  name  \
# 0    0_bj                   SALTED CARAMEL CORE
# 1    1_bj                   NETFLIX & CHILLL'D™
# 2    2_bj                          CHIP HAPPENS
# 3    3_bj                               CANNOLI
# 4    4_bj                        GIMME S’MORE!™
# 5    5_bj             PEANUT BUTTER HALF BAKED®
# 6    6_bj                BERRY SWEET MASCARPONE
# 7    7_bj         CHOCOLATE PEANUT BUTTER SPLIT
# 8    8_bj                     JUSTICE REMIX'D ™
# 9    9_bj                 BOOTS ON THE MOOOO’N™
# 10  10_bj                      AMERICONE DREAM®
# 11  11_bj                     BOURBON PECAN PIE
# 12  12_bj                     BREWED TO MATTER™
# 13  13_bj          CARAMEL CHOCOLATE CHEESECAKE
# 14  14_bj                        CHERRY GARCIA®
# 15  15_bj                   CHILLIN' THE ROAST™
# 16  16_bj           CHOCOLATE CHIP COOKIE DOUGH
# 17  17_bj               CHOCOLATE FUDGE BROWNIE
# ...

# %%
df['base_flavor'] = df['subhead'].str.split(' ICE CREAM').str[0]
df['base_flavor'] = df['base_flavor'].str.split(' OF').str.get(-1)
df['base_flavor'] = df['base_flavor'].str.strip()
df
# Out:
#       key                                  name  \
# 0    0_bj                   SALTED CARAMEL CORE
# 1    1_bj                   NETFLIX & CHILLL'D™
# 2    2_bj                          CHIP HAPPENS
# 3    3_bj                               CANNOLI
# 4    4_bj                        GIMME S’MORE!™
# 5    5_bj             PEANUT BUTTER HALF BAKED®
# 6    6_bj                BERRY SWEET MASCARPONE
# 7    7_bj         CHOCOLATE PEANUT BUTTER SPLIT
# 8    8_bj                     JUSTICE REMIX'D ™
# 9    9_bj                 BOOTS ON THE MOOOO’N™
# 10  10_bj                      AMERICONE DREAM®
# 11  11_bj                     BOURBON PECAN PIE
# 12  12_bj                     BREWED TO MATTER™
# 13  13_bj          CARAMEL CHOCOLATE CHEESECAKE
# 14  14_bj                        CHERRY GARCIA®
# 15  15_bj                   CHILLIN' THE ROAST™
# 16  16_bj           CHOCOLATE CHIP COOKIE DOUGH
# 17  17_bj               CHOCOLATE FUDGE BROWNIE
# ...

# %%
df.to_csv('bj_flavors.csv', index=False)
